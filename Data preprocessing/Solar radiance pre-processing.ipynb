# %%
import os, glob2
import pandas as pd
import numpy as np
import datetime

# %%
path_in = "/content/drive/MyDrive/Solar energy prediction - Project/Datasets/"
path_out = "/content/drive/MyDrive/Solar energy prediction - Project/Datasets/Out/"
sr_df = pd.read_csv(os.path.join(path_in, 'rayonnement-solaire-vitesse-vent-tri-horaires-regionaux.csv'), sep=';')
sr_df.head()
# Out:
#                         Date  ...  Rayonnement solaire global (W/m2)
# 0  2016-02-22T19:00:00+01:00  ...                               9.17
# 1  2017-08-15T14:00:00+02:00  ...                             516.22
# 2  2016-02-23T07:00:00+01:00  ...                               0.00
# 3  2017-08-16T05:00:00+02:00  ...                               0.00
# 4  2016-02-23T13:00:00+01:00  ...                             356.98
#
# [5 rows x 5 columns]

# %%
sr_df_idf = sr_df[sr_df['Code INSEE région']==11].reset_index(drop=True)

# %%
sr_df_idf.head()
# Out:
#                         Date  ...  Rayonnement solaire global (W/m2)
# 0  2016-02-23T07:00:00+01:00  ...                               0.00
# 1  2016-02-29T01:00:00+01:00  ...                               0.00
# 2  2016-02-21T19:00:00+01:00  ...                              32.61
# 3  2017-10-11T14:00:00+02:00  ...                             351.81
# 4  2017-06-13T17:00:00+02:00  ...                             796.48
#
# [5 rows x 5 columns]

# %%
sr_df_idf.Date = sr_df_idf.Date.str[:19]

# %%
sr_df_idf.head()
# Out:
#                   Date  ...  Rayonnement solaire global (W/m2)
# 0  2016-02-23T07:00:00  ...                               0.00
# 1  2016-02-29T01:00:00  ...                               0.00
# 2  2016-02-21T19:00:00  ...                              32.61
# 3  2017-10-11T14:00:00  ...                             351.81
# 4  2017-06-13T17:00:00  ...                             796.48
#
# [5 rows x 5 columns]

# %%
sr_df_idf.Date = pd.to_datetime(sr_df_idf.Date, format="%Y-%m-%dT%H:%M:%S")

# %%
sr_df_idf.set_index('Date', inplace=True)

# %%
sr_df_idf.loc['2017-01-01 01:00:00']
# Out:
# Code INSEE région                               11
# Région                               Ile-de-France
# Vitesse du vent à 100m (m/s)                  4.53
# Rayonnement solaire global (W/m2)                0
# Name: 2017-01-01 01:00:00, dtype: object

# %%
sr_df_idf.sort_index(inplace=True)
sr_df_idf.head()
# Out:
#                      Code INSEE région  ... Rayonnement solaire global (W/m2)
# Date                                    ...
# 2016-01-01 04:00:00                 11  ...                              0.00
# 2016-01-01 04:00:00                 11  ...                              0.00
# 2016-01-01 07:00:00                 11  ...                              0.00
# 2016-01-01 07:00:00                 11  ...                              0.00
# 2016-01-01 10:00:00                 11  ...                             12.12
#
# [5 rows x 4 columns]

# %%
sr_df_idf_dd = sr_df_idf[~sr_df_idf.index.duplicated(keep='first')]

# %%
sr_df_idf_dd.head()
# Out:
#                      Code INSEE région  ... Rayonnement solaire global (W/m2)
# Date                                    ...
# 2016-01-01 04:00:00                 11  ...                              0.00
# 2016-01-01 07:00:00                 11  ...                              0.00
# 2016-01-01 10:00:00                 11  ...                             12.12
# 2016-01-01 13:00:00                 11  ...                            179.61
# 2016-01-01 16:00:00                 11  ...                            114.67
#
# [5 rows x 4 columns]

# %%
df_1720 = sr_df_idf.loc['2017-01-01 00:00:00':'2020-12-31 23:59:59']

# %%
df_1720.head()
# Out:
#                      Code INSEE région  ... Rayonnement solaire global (W/m2)
# Date                                    ...
# 2017-01-01 01:00:00                 11  ...                              0.00
# 2017-01-01 04:00:00                 11  ...                              0.00
# 2017-01-01 07:00:00                 11  ...                              0.00
# 2017-01-01 10:00:00                 11  ...                              7.09
# 2017-01-01 13:00:00                 11  ...                             84.24
#
# [5 rows x 4 columns]

# %%
df_1720.tail()
# Out:
#                      Code INSEE région  ... Rayonnement solaire global (W/m2)
# Date                                    ...
# 2020-12-31 10:00:00                 11  ...                             42.83
# 2020-12-31 13:00:00                 11  ...                             94.23
# 2020-12-31 16:00:00                 11  ...                             96.84
# 2020-12-31 19:00:00                 11  ...                             34.93
# 2020-12-31 22:00:00                 11  ...                              0.00
#
# [5 rows x 4 columns]

# %%
df_1720.drop(columns=['Code INSEE région',	'Région'], inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_1720.head()
# Out:
#                      Vitesse du vent à 100m (m/s)  Rayonnement solaire global (W/m2)
# Date
# 2017-01-01 01:00:00                          4.53                               0.00
# 2017-01-01 04:00:00                          5.30                               0.00
# 2017-01-01 07:00:00                          4.92                               0.00
# 2017-01-01 10:00:00                          4.71                               7.09
# 2017-01-01 13:00:00                          4.30                              84.24

# %%
df_1720.to_csv(os.path.join(path_out, 'idf_2017-2020_three-hourly_solar_radiance.csv'))
